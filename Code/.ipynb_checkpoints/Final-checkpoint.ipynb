# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

from scipy import stats as stats
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score,GridSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import plot_confusion_matrix, confusion_matrix, plot_roc_curve, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import export_graphviz

import pickle

import requests
from bs4 import BeautifulSoup as bs
from bs4 import Comment

import regex
import datetime

from tqdm import tqdm

# %% [markdown]
# # Data Uploading & Cleaning

# %% [markdown]
# ## Upload & Clean Odds Data

# %% [markdown]
# Due to the unusual and shortened schedule in 2020, chose to drop.  Similarly for the not-yet-completed 2021 season.

# %%
years=['2019','2018','2017','2016','2015']
data={}

# %%
for yr in years:
    data[yr]=pd.read_excel('../Raw Data/'+yr+'.xlsx')

# %%
for yr,df in data.items():
    df_clean=df.drop(['Rot','1st','2nd','3rd','4th','5th','6th','7th','8th','9th','Open','Close','RunLine','Run Line','Unnamed: 18'],axis=1,errors='ignore')
    df_clean['year']=int(yr)
    df_clean['day']=df_clean.Date.apply(lambda x:x%100)
    df_clean['month']=df_clean.Date.apply(lambda x:int(np.round(x,-2)/100))
    df_clean['date']=df_clean.apply(lambda r:datetime.datetime(r.year,r.month,r.day),axis=1)
    df_clean.drop(['Date','day'],axis=1,inplace=True)
    data[yr]=df_clean.rename({'Open OU':'OpenOU','Close OU':'CloseOU','Unnamed: 20':'Open_Odds','Unnamed: 22':'Close_Odds'},axis=1)

# %%
all_data=pd.concat(data.values(),ignore_index=True)

# %%
patt=r'\-[A-Z]{1}'
all_data.Pitcher=all_data.Pitcher.str.replace(patt,'')

# %% [markdown]
# Checking team labels in the odds data, note a couple of issues to fix.

# %%
all_data.Team.value_counts()

# %% [markdown]
# First, some inconsistencent labeling (LOS v LA, e.g.).

# %%
all_data.Team.replace({'CUB':'CHC','LOS':'LAD','SFG':'SFO','BRS':'BOS'}).value_counts()

# %%
all_data.Team=all_data.Team.replace({'CUB':'CHC','LOS':'LAD','SFG':'SFO','BRS':'BOS'})

# %% [markdown]
# Second, need to adjust labels to be consistent with official labels.

# %%
all_data.Team=all_data.Team.replace({
                                    'KAN':'KCR',
                                    'TAM':'TBR',
                                    'SDG':'SDP',
                                    'WAS':'WSN',
                                    'SFO':'SFG',
                                    'CWS':'CHW'
                                    })

# %%
all_data

# %% [markdown]
# Next, looking at Home/Away labels, there are four (two games) rows which have neither.  Upon further expection, this comes from games played outside of the US.  Links:
#
# 1) https://www.baseball-reference.com/boxes/OAK/OAK201903200.shtml
#
# 2) https://www.baseball-reference.com/boxes/OAK/OAK201903210.shtml

# %%
all_data.VH.value_counts()

# %%
all_data[all_data.VH=='N']

# %%
all_data.at[0,'VH']='V'
all_data.at[1,'VH']='H'
all_data.at[2,'VH']='V'
all_data.at[3,'VH']='H'

# %%
all_data.head()

# %%
all_data.VH.value_counts()

# %% [markdown]
# Next, need to clean up a single observation with missing run data.  Link:
#
# https://www.baseball-reference.com/boxes/PIT/PIT201606071.shtml
#
# Convert column into integers.

# %%
all_data.Final.value_counts()

# %%
all_data[all_data.Final=='NL']

# %%
all_data.at[16276,'Final']=3
all_data.at[16277,'Final']=3

# %%
all_data.Final.value_counts()

# %%
all_data.Final=all_data.Final.astype(int)

# %% [markdown]
# Next looking @ the target variable, there are some outrageous values that cannot be explained.  Since there is no other resource to check for the correct value, replace the line @ close with the line @ open.
#
# Finally, convert the column into float.

# %%
all_data.CloseOU.value_counts()

# %%
all_data[all_data.CloseOU > 20]

# %%
all_data.CloseOU=all_data.apply(lambda r:r.OpenOU if r.CloseOU>20 else r.CloseOU,axis=1)

# %%
all_data.CloseOU.value_counts()

# %%
all_data.CloseOU=all_data.CloseOU.astype(float)

# %% [markdown]
# The original data is a bit confusing.  For each game, there are two rows in the dataset: one containing data for the Road team and one for the Home Team.  However, the over-under variable in both rows refers to the total runs scored.
#
# As a result, need to consolidate each row-pair into a single row with both Home and Away data.  Because the paired rows are adjacent, it is easy to combine.  This was done for each row--even though it adds significant execution time--and removed duplicates to be safe.

# %%
all_data['Home_Pitcher']=''
all_data['Away_Pitcher']=''
all_data['Home_Team']=''
all_data['Away_Team']=''
all_data['Home_Score']=0
all_data['Away_Score']=0
for i,row in all_data.iterrows():
    if row.VH=='V':
        all_data.loc[i,'Away_Pitcher']=all_data.loc[i,'Pitcher']
        all_data.loc[i,'Away_Team']=all_data.loc[i,'Team']
        all_data.loc[i,'Away_Score']=all_data.loc[i,'Final']
        all_data.loc[i,'Home_Score']=all_data.loc[i+1,'Final']
        all_data.loc[i,'Home_Team']=all_data.loc[i+1,'Team']
        all_data.loc[i,'Home_Pitcher']=all_data.loc[i+1,'Pitcher']
        pass
    elif row.VH=='H':
        all_data.loc[i,'Away_Pitcher']=all_data.loc[i-1,'Pitcher']
        all_data.loc[i,'Away_Team']=all_data.loc[i-1,'Team']
        all_data.loc[i,'Away_Score']=all_data.loc[i-1,'Final']
        all_data.loc[i,'Home_Score']=all_data.loc[i,'Final']
        all_data.loc[i,'Home_Team']=all_data.loc[i,'Team']
        all_data.loc[i,'Home_Pitcher']=all_data.loc[i,'Pitcher']
        pass
    else:
        pass
all_data

# %%
all_data=all_data.drop_duplicates(subset=['Away_Pitcher','Home_Pitcher','date'],ignore_index=True)
all_data

# %% [markdown]
# At this point, it makes sense to start dropping some unneeded rows.

# %%
all_data.drop(['VH','Team','Pitcher','Final','OpenOU','Open_Odds'],axis=1,inplace=True)
all_data

# %% [markdown]
# Finally, create some additional features:  Total Runs; OVER Dummy Variable; and a key value.
#
# To build the key value, start with date + Home Team (later date sources will use a similar key).  However, because of double-headers, this does not create unique key values.  Next, tried date combined with the runs scored by the home and away team.  This works well with one exception where both games in a double header ended in the same score.  These observations' key-values were manually adjusted.

# %%
all_data['Total_Runs']=all_data['Home_Score']+all_data['Away_Score']
all_data['OVER']=all_data.apply(lambda r:r.Total_Runs>r.CloseOU,axis=1)
all_data

# %%
all_data['KEY']=all_data.date.apply(lambda d:str(d).replace(' 00:00:00','-'))+all_data.Home_Team

# %%
all_data[all_data.KEY.duplicated(keep=False)]

# %%
all_data.KEY=all_data.apply(lambda r:r.KEY+str(r.Home_Score)+str(r.Away_Score),axis=1)
all_data[all_data.KEY.duplicated(keep=False)]

# %%
all_data.at[8147,'KEY']=all_data.at[8147,'KEY']='A'
all_data.at[8162,'KEY']=all_data.at[8162,'KEY']='B'

# %%
all_data

# %%
all_data.to_pickle('../Base DFs/Odds_Data.pkl')

# %%
# %reset -f

# %% [markdown]
# ## Upload information on each game in the dataset.

# %%
TEAMS={}
with open('../Teams.txt') as f:
    for r in f.readlines():
        t=r.split(',')
        TEAMS[t[0]]=t[1]

YRs=['2019','2018','2017','2016','2015']
odds_data=pd.read_pickle('../Base DFs/Odds_Data.pkl')

# %% [markdown]
# On the baseball-reference website, there is a page with the entire year schedule for all teams.

# %%
s_patt=r'([A-Za-z .\']+) \(([0-9]{1,2})\)\s{0,2}\@ ([A-Za-z .\']+) \(([0-9]{1,2})\)'
s_rgx=regex.compile(s_patt)
d_patt=r'[A-Z]{3}([0-9]{8})[0-9]{1}\.shtml'
d_rgx=regex.compile(d_patt)

# %%
game_data=[]
for yr in YRs:
    link='https://www.baseball-reference.com/leagues/MLB/'+yr+'-schedule.shtml'
    r=requests.get(link)
    soup=bs(r.content)
    table=soup.find('span',attrs={'data-label':'MLB Schedule'}).parent.find_next_sibling('div')
    games=table.find_all('p',attrs={'class':'game'})
    for g in tqdm(games):
        s=' '.join(g.stripped_strings)
        info=s_rgx.search(s).groups()
        links=g.find_all('a')
        l=links[-1]['href']
        d={'Away_Team':links[0]['href'],
           'Home_Team':links[1]['href'],
           'Away_Score':info[1],
           'Home_Score':info[3],
           'link':l,
           'date':pd.to_datetime(d_rgx.search(l).groups()[0],format='%Y%m%d')
          }
        game_data.append(d)
# Out:
# 100%|██████████| 2429/2429 [00:00<00:00, 6110.53it/s]
# 100%|██████████| 2431/2431 [00:00<00:00, 6637.94it/s]
# 100%|██████████| 2430/2430 [00:00<00:00, 6692.91it/s]
# 100%|██████████| 2428/2428 [00:00<00:00, 6596.37it/s]
# 100%|██████████| 2429/2429 [00:00<00:00, 6531.42it/s]

# %%
len(game_data)
# Out:
# 12147

# %%
games_meta=pd.DataFrame(game_data)
games_meta
# Out:
#                    Away_Team              Home_Team Away_Score Home_Score  \
# 0      /teams/SEA/2019.shtml  /teams/OAK/2019.shtml          9          7
# 1      /teams/SEA/2019.shtml  /teams/OAK/2019.shtml          5          4
# 2      /teams/PIT/2019.shtml  /teams/CIN/2019.shtml          3          5
# 3      /teams/CHW/2019.shtml  /teams/KCR/2019.shtml          3          5
# 4      /teams/ARI/2019.shtml  /teams/LAD/2019.shtml          5         12
# ...                      ...                    ...        ...        ...
# 12142  /teams/CIN/2015.shtml  /teams/PIT/2015.shtml          0          4
# 12143  /teams/OAK/2015.shtml  /teams/SEA/2015.shtml          2          3
# 12144  /teams/COL/2015.shtml  /teams/SFG/2015.shtml          7          3
# 12145  /teams/TOR/2015.shtml  /teams/TBR/2015.shtml          3         12
# 12146  /teams/LAA/2015.shtml  /teams/TEX/2015.shtml          2          9
#
#                                 link       date
# 0      /boxes/OAK/OAK201903200.shtml 2019-03-20
# 1      /boxes/OAK/OAK201903210.shtml 2019-03-21
# 2      /boxes/CIN/CIN201903280.shtml 2019-03-28
# 3      /boxes/KCA/KCA201903280.shtml 2019-03-28
# 4      /boxes/LAN/LAN201903280.shtml 2019-03-28
# ...                              ...        ...
# 12142  /boxes/PIT/PIT201510040.shtml 2015-10-04
# 12143  /boxes/SEA/SEA201510040.shtml 2015-10-04
# 12144  /boxes/SFN/SFN201510040.shtml 2015-10-04
# 12145  /boxes/TBA/TBA201510040.shtml 2015-10-04
# 12146  /boxes/TEX/TEX201510040.shtml 2015-10-04
#
# [12147 rows x 6 columns]

# %%
patt=r'\/teams\/([A-Z]{3})\/[0-9]{4}\.shtml'
games_meta.Away_Team=games_meta.Away_Team.str.extract(patt)
games_meta.Home_Team=games_meta.Home_Team.str.extract(patt)
games_meta
# Out:
#       Away_Team Home_Team Away_Score Home_Score  \
# 0           SEA       OAK          9          7
# 1           SEA       OAK          5          4
# 2           PIT       CIN          3          5
# 3           CHW       KCR          3          5
# 4           ARI       LAD          5         12
# ...         ...       ...        ...        ...
# 12142       CIN       PIT          0          4
# 12143       OAK       SEA          2          3
# 12144       COL       SFG          7          3
# 12145       TOR       TBR          3         12
# 12146       LAA       TEX          2          9
#
#                                 link       date
# 0      /boxes/OAK/OAK201903200.shtml 2019-03-20
# 1      /boxes/OAK/OAK201903210.shtml 2019-03-21
# 2      /boxes/CIN/CIN201903280.shtml 2019-03-28
# 3      /boxes/KCA/KCA201903280.shtml 2019-03-28
# 4      /boxes/LAN/LAN201903280.shtml 2019-03-28
# ...                              ...        ...
# 12142  /boxes/PIT/PIT201510040.shtml 2015-10-04
# 12143  /boxes/SEA/SEA201510040.shtml 2015-10-04
# 12144  /boxes/SFN/SFN201510040.shtml 2015-10-04
# 12145  /boxes/TBA/TBA201510040.shtml 2015-10-04
# 12146  /boxes/TEX/TEX201510040.shtml 2015-10-04
#
# [12147 rows x 6 columns]

# %%
games_meta['KEY']=games_meta.date.apply(lambda d:str(d).replace(' 00:00:00','-'))+games_meta.Home_Team
sum(games_meta.KEY.duplicated(keep=False))
# Out:
# 278

# %%
games_meta.KEY=games_meta.apply(lambda r:r.KEY+str(r.Home_Score)+str(r.Away_Score),axis=1)
games_meta[games_meta.KEY.duplicated(keep=False)]
# Out:
#      Away_Team Home_Team Away_Score Home_Score                           link  \
# 8158       NYM       PIT          1          3  /boxes/PIT/PIT201606071.shtml
# 8159       NYM       PIT          1          3  /boxes/PIT/PIT201606072.shtml
#
#            date               KEY
# 8158 2016-06-07  2016-06-07-PIT31
# 8159 2016-06-07  2016-06-07-PIT31

# %%
games_meta.at[8158,'KEY']=games_meta.at[8158,'KEY']='A'
games_meta.at[8159,'KEY']=games_meta.at[8159,'KEY']='B'

# %%
games_meta
# Out:
#       Away_Team Home_Team Away_Score Home_Score  \
# 0           SEA       OAK          9          7
# 1           SEA       OAK          5          4
# 2           PIT       CIN          3          5
# 3           CHW       KCR          3          5
# 4           ARI       LAD          5         12
# ...         ...       ...        ...        ...
# 12142       CIN       PIT          0          4
# 12143       OAK       SEA          2          3
# 12144       COL       SFG          7          3
# 12145       TOR       TBR          3         12
# 12146       LAA       TEX          2          9
#
#                                 link       date                KEY
# 0      /boxes/OAK/OAK201903200.shtml 2019-03-20   2019-03-20-OAK79
# 1      /boxes/OAK/OAK201903210.shtml 2019-03-21   2019-03-21-OAK45
# 2      /boxes/CIN/CIN201903280.shtml 2019-03-28   2019-03-28-CIN53
# 3      /boxes/KCA/KCA201903280.shtml 2019-03-28   2019-03-28-KCR53
# 4      /boxes/LAN/LAN201903280.shtml 2019-03-28  2019-03-28-LAD125
# ...                              ...        ...                ...
# 12142  /boxes/PIT/PIT201510040.shtml 2015-10-04   2015-10-04-PIT40
# 12143  /boxes/SEA/SEA201510040.shtml 2015-10-04   2015-10-04-SEA32
# 12144  /boxes/SFN/SFN201510040.shtml 2015-10-04   2015-10-04-SFG37
# 12145  /boxes/TBA/TBA201510040.shtml 2015-10-04  2015-10-04-TBR123
# 12146  /boxes/TEX/TEX201510040.shtml 2015-10-04   2015-10-04-TEX92
#
# [12147 rows x 7 columns]

# %%
games_meta.to_pickle('../Base DFs/Games_Meta.pkl')

# %%
X=pd.merge(games_meta,odds_data,on='KEY',how='outer')
'''
errors=pd.concat([X[X.date_x.isna()],X[X.date_y.isna()]],axis=0)
errors['date']=errors.apply(lambda r:(r.date_x,r.date_y)[r.date_x is pd.NaT],axis=1)

errors['home']=errors.apply(lambda r:(r.Home_Team_x,r.Home_Team_y)[r.date_x is pd.NaT],axis=1)
errors=errors.sort_values(['date','home'])
errors=errors.reset_index()
errors
'''
X.dropna(subset=['Away_Team_x','Away_Team_y'])
# Out:
#       Away_Team_x Home_Team_x Away_Score_x Home_Score_x  \
# 0             SEA         OAK            9            7
# 1             SEA         OAK            5            4
# 2             PIT         CIN            3            5
# 3             CHW         KCR            3            5
# 4             ARI         LAD            5           12
# ...           ...         ...          ...          ...
# 12142         CIN         PIT            0            4
# 12143         OAK         SEA            2            3
# 12144         COL         SFG            7            3
# 12145         TOR         TBR            3           12
# 12146         LAA         TEX            2            9
#
#                                 link     date_x                KEY  CloseOU  \
# 0      /boxes/OAK/OAK201903200.shtml 2019-03-20   2019-03-20-OAK79      8.5
# 1      /boxes/OAK/OAK201903210.shtml 2019-03-21   2019-03-21-OAK45      9.0
# 2      /boxes/CIN/CIN201903280.shtml 2019-03-28   2019-03-28-CIN53      8.5
# 3      /boxes/KCA/KCA201903280.shtml 2019-03-28   2019-03-28-KCR53      8.5
# 4      /boxes/LAN/LAN201903280.shtml 2019-03-28  2019-03-28-LAD125      7.0
# ...                              ...        ...                ...      ...
# 12142  /boxes/PIT/PIT201510040.shtml 2015-10-04   2015-10-04-PIT40      7.5
# 12143  /boxes/SEA/SEA201510040.shtml 2015-10-04   2015-10-04-SEA32      7.5
# 12144  /boxes/SFN/SFN201510040.shtml 2015-10-04   2015-10-04-SFG37      7.5
# 12145  /boxes/TBA/TBA201510040.shtml 2015-10-04  2015-10-04-TBR123      8.5
# 12146  /boxes/TEX/TEX201510040.shtml 2015-10-04   2015-10-04-TEX92      8.5
#
#        Close_Odds    year  month     date_y Home_Pitcher Away_Pitcher  \
# 0          -120.0  2019.0    3.0 2019-03-20       MFIERS    MGONZALES
# 1          -130.0  2019.0    3.0 2019-03-21     MESTRADA     YKIKUCHI
# 2          -105.0  2019.0    3.0 2019-03-28    LCASTILLO     JTAILLON
# 3          -105.0  2019.0    3.0 2019-03-28      BKELLER       CRODON
# 4          -120.0  2019.0    3.0 2019-03-28         HRYU     ZGREINKE
# ...           ...     ...    ...        ...          ...          ...
# 12142      -105.0  2015.0   10.0 2015-10-04        JHAPP       JSMITH
# 12143      -115.0  2015.0   10.0 2015-10-04        VNUNO     CBASSITT
# 12144      -115.0  2015.0   10.0 2015-10-04        MCAIN     CBERGMAN
# 12145      -120.0  2015.0   10.0 2015-10-04       MMOORE     MBUEHRLE
# 12146      -115.0  2015.0   10.0 2015-10-04      CHAMELS    GRICHARDS
#
#       Home_Team_y Away_Team_y  Home_Score_y  Away_Score_y  Total_Runs   OVER
# 0             OAK         SEA           7.0           9.0        16.0   True
# 1             OAK         SEA           4.0           5.0         9.0  False
# 2             CIN         PIT           5.0           3.0         8.0  False
# 3             KCR         CHW           5.0           3.0         8.0  False
# 4             LAD         ARI          12.0           5.0        17.0   True
# ...           ...         ...           ...           ...         ...    ...
# 12142         PIT         CIN           4.0           0.0         4.0  False
# 12143         SEA         OAK           3.0           2.0         5.0  False
# 12144         SFG         COL           3.0           7.0        10.0   True
# 12145         TBR         TOR          12.0           3.0        15.0   True
# 12146         TEX         LAA           9.0           2.0        11.0   True
#
# [12116 rows x 20 columns]

# %%
game_data=pd.merge(games_meta,odds_data,on='KEY',how='inner')
game_data=game_data.drop(['Away_Score_y','Home_Score_y','Away_Team_y','Home_Team_y','Total_Runs','date_y'],axis=1)
game_data=game_data.rename({'Away_Score_x':'Away_Score','Home_Score_x':'Home_Score','Away_Team_x':'Away_Team','Home_Team_x':'Home_Team','date_x':'date'},axis=1)
game_data=game_data.astype({'Away_Score':'int64','Home_Score':'int64','Close_Odds':'int64','month':'int64','year':'int64'})
game_data.CloseOU=game_data.CloseOU.astype(float)
game_data['Total_Runs']=game_data.Away_Score+game_data.Home_Score
game_data
# Out:
#       Away_Team Home_Team  Away_Score  Home_Score  \
# 0           SEA       OAK           9           7
# 1           SEA       OAK           5           4
# 2           PIT       CIN           3           5
# 3           CHW       KCR           3           5
# 4           ARI       LAD           5          12
# ...         ...       ...         ...         ...
# 12111       CIN       PIT           0           4
# 12112       OAK       SEA           2           3
# 12113       COL       SFG           7           3
# 12114       TOR       TBR           3          12
# 12115       LAA       TEX           2           9
#
#                                 link       date                KEY  CloseOU  \
# 0      /boxes/OAK/OAK201903200.shtml 2019-03-20   2019-03-20-OAK79      8.5
# 1      /boxes/OAK/OAK201903210.shtml 2019-03-21   2019-03-21-OAK45      9.0
# 2      /boxes/CIN/CIN201903280.shtml 2019-03-28   2019-03-28-CIN53      8.5
# 3      /boxes/KCA/KCA201903280.shtml 2019-03-28   2019-03-28-KCR53      8.5
# 4      /boxes/LAN/LAN201903280.shtml 2019-03-28  2019-03-28-LAD125      7.0
# ...                              ...        ...                ...      ...
# 12111  /boxes/PIT/PIT201510040.shtml 2015-10-04   2015-10-04-PIT40      7.5
# 12112  /boxes/SEA/SEA201510040.shtml 2015-10-04   2015-10-04-SEA32      7.5
# 12113  /boxes/SFN/SFN201510040.shtml 2015-10-04   2015-10-04-SFG37      7.5
# 12114  /boxes/TBA/TBA201510040.shtml 2015-10-04  2015-10-04-TBR123      8.5
# 12115  /boxes/TEX/TEX201510040.shtml 2015-10-04   2015-10-04-TEX92      8.5
#
#        Close_Odds  year  month Home_Pitcher Away_Pitcher   OVER  Total_Runs
# 0            -120  2019      3       MFIERS    MGONZALES   True          16
# 1            -130  2019      3     MESTRADA     YKIKUCHI  False           9
# 2            -105  2019      3    LCASTILLO     JTAILLON  False           8
# 3            -105  2019      3      BKELLER       CRODON  False           8
# 4            -120  2019      3         HRYU     ZGREINKE   True          17
# ...           ...   ...    ...          ...          ...    ...         ...
# 12111        -105  2015     10        JHAPP       JSMITH  False           4
# 12112        -115  2015     10        VNUNO     CBASSITT  False           5
# 12113        -115  2015     10        MCAIN     CBERGMAN   True          10
# 12114        -120  2015     10       MMOORE     MBUEHRLE   True          15
# 12115        -115  2015     10      CHAMELS    GRICHARDS   True          11
#
# [12116 rows x 15 columns]

# %%
base='https://www.baseball-reference.com/teams/{t}/{y}-schedule-scores.shtml'
stats=['boxscore','day_or_night','attendance','cli']
game_stats={}

# %%
for yr in YRs:
    for team in TEAMS.keys():
        link=base.format_map({'t':team,'y':yr})
        r=requests.get(link)
        soup=bs(r.content)
        table=soup.find('table',attrs={'id':'team_schedule'}).tbody
        games=table.find_all('tr')
        i=1
        for g in games:
            info=g.find_all('td',attrs={'data-stat':stats})
            if(info):
                link=info[0].a['href']
                d=dict(zip(stats[1:],[col.text for col in info[1:]]))
                d['link']=link
                game_stats[team+'_'+yr+'_'+str(i)]=d
                i+=1

# %%
game_logs=pd.DataFrame.from_dict(game_stats,orient='index')
#game_logs.attendance=game_logs.attendance.astype(int)
#game_logs.cli=game_logs.cli.astype(float)
game_logs.to_pickle('../Base DFs/Games_Info_I.pkl')
game_logs
# Out:
#              day_or_night attendance   cli                           link
# ARI_2019_1              D     53,086  1.08  /boxes/LAN/LAN201903280.shtml
# ARI_2019_2              N     42,266   .99  /boxes/LAN/LAN201903290.shtml
# ARI_2019_3              N     50,626  1.06  /boxes/LAN/LAN201903300.shtml
# ARI_2019_4              D     43,815  1.04  /boxes/LAN/LAN201903310.shtml
# ARI_2019_5              N     18,683   .98  /boxes/SDN/SDN201904010.shtml
# ...                   ...        ...   ...                            ...
# WSN_2015_158            N     13,860   .00  /boxes/ATL/ATL201509300.shtml
# WSN_2015_159            N     37,790   .00  /boxes/ATL/ATL201510010.shtml
# WSN_2015_160            D     39,465   .00  /boxes/NYN/NYN201510031.shtml
# WSN_2015_161            N     41,480   .00  /boxes/NYN/NYN201510032.shtml
# WSN_2015_162            D     41,631   .00  /boxes/NYN/NYN201510040.shtml
#
# [24294 rows x 4 columns]

# %%
game_data=pd.merge(game_data,game_logs.drop_duplicates(['link']),left_on=['link'],right_on=['link'])
game_data
# Out:
#       Away_Team Home_Team  Away_Score  Home_Score  \
# 0           SEA       OAK           9           7
# 1           SEA       OAK           5           4
# 2           PIT       CIN           3           5
# 3           CHW       KCR           3           5
# 4           ARI       LAD           5          12
# ...         ...       ...         ...         ...
# 12111       CIN       PIT           0           4
# 12112       OAK       SEA           2           3
# 12113       COL       SFG           7           3
# 12114       TOR       TBR           3          12
# 12115       LAA       TEX           2           9
#
#                                 link       date                KEY  CloseOU  \
# 0      /boxes/OAK/OAK201903200.shtml 2019-03-20   2019-03-20-OAK79      8.5
# 1      /boxes/OAK/OAK201903210.shtml 2019-03-21   2019-03-21-OAK45      9.0
# 2      /boxes/CIN/CIN201903280.shtml 2019-03-28   2019-03-28-CIN53      8.5
# 3      /boxes/KCA/KCA201903280.shtml 2019-03-28   2019-03-28-KCR53      8.5
# 4      /boxes/LAN/LAN201903280.shtml 2019-03-28  2019-03-28-LAD125      7.0
# ...                              ...        ...                ...      ...
# 12111  /boxes/PIT/PIT201510040.shtml 2015-10-04   2015-10-04-PIT40      7.5
# 12112  /boxes/SEA/SEA201510040.shtml 2015-10-04   2015-10-04-SEA32      7.5
# 12113  /boxes/SFN/SFN201510040.shtml 2015-10-04   2015-10-04-SFG37      7.5
# 12114  /boxes/TBA/TBA201510040.shtml 2015-10-04  2015-10-04-TBR123      8.5
# 12115  /boxes/TEX/TEX201510040.shtml 2015-10-04   2015-10-04-TEX92      8.5
#
#        Close_Odds  year  month Home_Pitcher Away_Pitcher   OVER  Total_Runs  \
# 0            -120  2019      3       MFIERS    MGONZALES   True          16
# 1            -130  2019      3     MESTRADA     YKIKUCHI  False           9
# 2            -105  2019      3    LCASTILLO     JTAILLON  False           8
# 3            -105  2019      3      BKELLER       CRODON  False           8
# 4            -120  2019      3         HRYU     ZGREINKE   True          17
# ...           ...   ...    ...          ...          ...    ...         ...
# 12111        -105  2015     10        JHAPP       JSMITH  False           4
# 12112        -115  2015     10        VNUNO     CBASSITT  False           5
# 12113        -115  2015     10        MCAIN     CBERGMAN   True          10
# 12114        -120  2015     10       MMOORE     MBUEHRLE   True          15
# 12115        -115  2015     10      CHAMELS    GRICHARDS   True          11
#
#       day_or_night attendance   cli
# 0                N     45,787  1.10
# 1                N     46,451  1.01
# 2                D     44,049  1.06
# 3                N     31,675  1.08
# 4                D     53,086  1.08
# ...            ...        ...   ...
# 12111            D     35,362   .00
# 12112            D     22,402   .00
# 12113            D     41,399   .00
# 12114            D     15,815   .00
# 12115            D     45,772  2.59
#
# [12116 rows x 18 columns]

# %%
base='https://www.baseball-reference.com'
more_data={}
#checked=[]

for game in tqdm(game_data.link):
    #if(game in checked):
    #    pass
    #else:
    #    checked.append(game)
    try:
        D={}
        link=base+game
        r=requests.get(link)
        soup=bs(r.content)
        X=soup.find('span',attrs={'data-label':'Pitching Lines and Info'}).parent.parent
        lineups=bs(X.find_all(text=lambda text:isinstance(text,Comment))[0]).find_all('table')
        pitcher=lineups[0].tbody.tr.th.a
        D['Away_Pitch']=(pitcher.text,pitcher['href'])
        pitcher=lineups[1].tbody.tr.th.a
        D['Home_Pitch']=(pitcher.text,pitcher['href'])
        X=soup.find('span',attrs={'data-label':'Other Info'}).parent.parent
        other=bs(X.find_all(text=lambda text:isinstance(text,Comment))[0])
        D['other']=other.text.strip()
        more_data[game]=D
    except:
        print(game)
        pass
# Out:
# 100%|██████████| 12116/12116 [43:12<00:00,  4.67it/s]

# %%
game_detail=pd.DataFrame.from_dict(more_data,orient='index')
game_detail
# Out:
#                                                                     Away_Pitch  \
# /boxes/OAK/OAK201903200.shtml     (Marco Gonzales, /players/g/gonzama02.shtml)
# /boxes/OAK/OAK201903210.shtml      (Yusei Kikuchi, /players/k/kikucyu01.shtml)
# /boxes/CIN/CIN201903280.shtml    (Jameson Taillon, /players/t/taillja01.shtml)
# /boxes/KCA/KCA201903280.shtml       (Carlos Rodon, /players/r/rodonca01.shtml)
# /boxes/LAN/LAN201903280.shtml       (Zack Greinke, /players/g/greinza01.shtml)
# ...                                                                        ...
# /boxes/PIT/PIT201510040.shtml      (Josh A. Smith, /players/s/smithjo07.shtml)
# /boxes/SEA/SEA201510040.shtml      (Chris Bassitt, /players/b/bassich01.shtml)
# /boxes/SFN/SFN201510040.shtml  (Christian Bergman, /players/b/bergmch01.shtml)
# /boxes/TBA/TBA201510040.shtml       (Mark Buehrle, /players/b/buehrma01.shtml)
# /boxes/TEX/TEX201510040.shtml   (Garrett Richards, /players/r/richaga01.shtml)
#
#                                                                 Home_Pitch  \
# /boxes/OAK/OAK201903200.shtml     (Mike Fiers, /players/f/fiersmi01.shtml)
# /boxes/OAK/OAK201903210.shtml  (Marco Estrada, /players/e/estrama01.shtml)
# /boxes/CIN/CIN201903280.shtml  (Luis Castillo, /players/c/castilu02.shtml)
# /boxes/KCA/KCA201903280.shtml    (Brad Keller, /players/k/kellebr01.shtml)
# /boxes/LAN/LAN201903280.shtml     (Hyun Jin Ryu, /players/r/ryuhy01.shtml)
# ...                                                                    ...
# /boxes/PIT/PIT201510040.shtml       (J.A. Happ, /players/h/happja01.shtml)
# /boxes/SEA/SEA201510040.shtml  (Vidal Nuno III, /players/n/nunovi01.shtml)
# /boxes/SFN/SFN201510040.shtml       (Matt Cain, /players/c/cainma01.shtml)
# /boxes/TBA/TBA201510040.shtml     (Matt Moore, /players/m/moorema02.shtml)
# /boxes/TEX/TEX201510040.shtml    (Cole Hamels, /players/h/hamelco01.shtml)
#
#                                                                            other
# /boxes/OAK/OAK201903200.shtml  Umpires: HP - Jeff Nelson, 1B - Tripp Gibson, ...
# /boxes/OAK/OAK201903210.shtml  Umpires: HP - Bill Welke, 1B - Lance Barksdale...
# /boxes/CIN/CIN201903280.shtml  Umpires: HP - Joe West, 1B - Eric Cooper, 2B -...
# /boxes/KCA/KCA201903280.shtml  Umpires: HP - Jerry Meals, 1B - Ron Kulpa, 2B ...
# /boxes/LAN/LAN201903280.shtml  Umpires: HP - Brian Gorman, 1B - Scott Barry, ...
# ...                                                                          ...
# /boxes/PIT/PIT201510040.shtml  Umpires: HP - Tim Welke, 1B - Todd Tichenor, 2...
# /boxes/SEA/SEA201510040.shtml  Umpires: HP - Mike Estabrook, 1B - Ed Hickox, ...
# /boxes/SFN/SFN201510040.shtml  Umpires: HP - Carlos Torres, 1B - Andy Fletche...
# /boxes/TBA/TBA201510040.shtml  Umpires: HP - Alfonso Marquez, 1B - Tom Hallio...
# /boxes/TEX/TEX201510040.shtml  Umpires: HP - Gary Cederstrom, 1B - Quinn Wolc...
#
# [12116 rows x 3 columns]

# %%
game_detail.to_pickle('../Base DFs/Games_Info_II.pkl')

# %%
game_data=pd.merge(game_data,game_detail,how='left',right_index=True,left_on=['link'])
game_data
# Out:
#       Away_Team Home_Team  Away_Score  Home_Score  \
# 0           SEA       OAK           9           7
# 1           SEA       OAK           5           4
# 2           PIT       CIN           3           5
# 3           CHW       KCR           3           5
# 4           ARI       LAD           5          12
# ...         ...       ...         ...         ...
# 12111       CIN       PIT           0           4
# 12112       OAK       SEA           2           3
# 12113       COL       SFG           7           3
# 12114       TOR       TBR           3          12
# 12115       LAA       TEX           2           9
#
#                                 link       date                KEY  CloseOU  \
# 0      /boxes/OAK/OAK201903200.shtml 2019-03-20   2019-03-20-OAK79      8.5
# 1      /boxes/OAK/OAK201903210.shtml 2019-03-21   2019-03-21-OAK45      9.0
# 2      /boxes/CIN/CIN201903280.shtml 2019-03-28   2019-03-28-CIN53      8.5
# 3      /boxes/KCA/KCA201903280.shtml 2019-03-28   2019-03-28-KCR53      8.5
# 4      /boxes/LAN/LAN201903280.shtml 2019-03-28  2019-03-28-LAD125      7.0
# ...                              ...        ...                ...      ...
# 12111  /boxes/PIT/PIT201510040.shtml 2015-10-04   2015-10-04-PIT40      7.5
# 12112  /boxes/SEA/SEA201510040.shtml 2015-10-04   2015-10-04-SEA32      7.5
# 12113  /boxes/SFN/SFN201510040.shtml 2015-10-04   2015-10-04-SFG37      7.5
# 12114  /boxes/TBA/TBA201510040.shtml 2015-10-04  2015-10-04-TBR123      8.5
# 12115  /boxes/TEX/TEX201510040.shtml 2015-10-04   2015-10-04-TEX92      8.5
#
#        Close_Odds  year  ...  Home_Pitcher Away_Pitcher   OVER  Total_Runs  \
# 0            -120  2019  ...        MFIERS    MGONZALES   True          16
# 1            -130  2019  ...      MESTRADA     YKIKUCHI  False           9
# 2            -105  2019  ...     LCASTILLO     JTAILLON  False           8
# 3            -105  2019  ...       BKELLER       CRODON  False           8
# 4            -120  2019  ...          HRYU     ZGREINKE   True          17
# ...           ...   ...  ...           ...          ...    ...         ...
# 12111        -105  2015  ...         JHAPP       JSMITH  False           4
# 12112        -115  2015  ...         VNUNO     CBASSITT  False           5
# 12113        -115  2015  ...         MCAIN     CBERGMAN   True          10
# 12114        -120  2015  ...        MMOORE     MBUEHRLE   True          15
# 12115        -115  2015  ...       CHAMELS    GRICHARDS   True          11
#
#        day_or_night attendance   cli  \
# 0                 N     45,787  1.10
# 1                 N     46,451  1.01
# 2                 D     44,049  1.06
# 3                 N     31,675  1.08
# 4                 D     53,086  1.08
# ...             ...        ...   ...
# 12111             D     35,362   .00
# 12112             D     22,402   .00
# 12113             D     41,399   .00
# 12114             D     15,815   .00
# 12115             D     45,772  2.59
#
#                                             Away_Pitch  \
# 0         (Marco Gonzales, /players/g/gonzama02.shtml)
# 1          (Yusei Kikuchi, /players/k/kikucyu01.shtml)
# 2        (Jameson Taillon, /players/t/taillja01.shtml)
# 3           (Carlos Rodon, /players/r/rodonca01.shtml)
# 4           (Zack Greinke, /players/g/greinza01.shtml)
# ...                                                ...
# 12111      (Josh A. Smith, /players/s/smithjo07.shtml)
# 12112      (Chris Bassitt, /players/b/bassich01.shtml)
# 12113  (Christian Bergman, /players/b/bergmch01.shtml)
# 12114       (Mark Buehrle, /players/b/buehrma01.shtml)
# 12115   (Garrett Richards, /players/r/richaga01.shtml)
#
#                                         Home_Pitch  \
# 0         (Mike Fiers, /players/f/fiersmi01.shtml)
# 1      (Marco Estrada, /players/e/estrama01.shtml)
# 2      (Luis Castillo, /players/c/castilu02.shtml)
# 3        (Brad Keller, /players/k/kellebr01.shtml)
# 4         (Hyun Jin Ryu, /players/r/ryuhy01.shtml)
# ...                                            ...
# 12111       (J.A. Happ, /players/h/happja01.shtml)
# 12112  (Vidal Nuno III, /players/n/nunovi01.shtml)
# 12113       (Matt Cain, /players/c/cainma01.shtml)
# 12114     (Matt Moore, /players/m/moorema02.shtml)
# 12115    (Cole Hamels, /players/h/hamelco01.shtml)
#
#                                                    other
# 0      Umpires: HP - Jeff Nelson, 1B - Tripp Gibson, ...
# 1      Umpires: HP - Bill Welke, 1B - Lance Barksdale...
# 2      Umpires: HP - Joe West, 1B - Eric Cooper, 2B -...
# 3      Umpires: HP - Jerry Meals, 1B - Ron Kulpa, 2B ...
# 4      Umpires: HP - Brian Gorman, 1B - Scott Barry, ...
# ...                                                  ...
# 12111  Umpires: HP - Tim Welke, 1B - Todd Tichenor, 2...
# 12112  Umpires: HP - Mike Estabrook, 1B - Ed Hickox, ...
# 12113  Umpires: HP - Carlos Torres, 1B - Andy Fletche...
# 12114  Umpires: HP - Alfonso Marquez, 1B - Tom Hallio...
# 12115  Umpires: HP - Gary Cederstrom, 1B - Quinn Wolc...
#
# [12116 rows x 21 columns]

# %%
game_data.columns
# Out:
# Index(['Away_Team', 'Home_Team', 'Away_Score', 'Home_Score', 'link', 'date',
#        'KEY', 'CloseOU', 'Close_Odds', 'year', 'month', 'Home_Pitcher',
#        'Away_Pitcher', 'OVER', 'Total_Runs', 'day_or_night', 'attendance',
#        'cli', 'Away_Pitch', 'Home_Pitch', 'other'],
#       dtype='object')

# %%
game_data['Away_Pitcher_Name']=game_data.Away_Pitch.apply(lambda t:t[0])
game_data['Away_Pitcher_ID']=game_data.Away_Pitch.apply(lambda t:t[1])

game_data['Home_Pitcher_Name']=game_data.Home_Pitch.apply(lambda t:t[0])
game_data['Home_Pitcher_ID']=game_data.Home_Pitch.apply(lambda t:t[1])
game_data.Home_Pitcher=game_data.Home_Pitch
game_data.Away_Pitcher=game_data.Away_Pitch
game_data.drop(['Away_Pitch','Home_Pitch'],inplace=True,axis=1,errors='ignore')

# %%
print(game_data.columns)
game_data
# Out:
# Index(['Away_Team', 'Home_Team', 'Away_Score', 'Home_Score', 'link', 'date',
#        'KEY', 'CloseOU', 'Close_Odds', 'year', 'month', 'Home_Pitcher',
#        'Away_Pitcher', 'OVER', 'Total_Runs', 'day_or_night', 'attendance',
#        'cli', 'other', 'Away_Pitcher_Name', 'Away_Pitcher_ID',
#        'Home_Pitcher_Name', 'Home_Pitcher_ID'],
#       dtype='object')
#       Away_Team Home_Team  Away_Score  Home_Score  \
# 0           SEA       OAK           9           7
# 1           SEA       OAK           5           4
# 2           PIT       CIN           3           5
# 3           CHW       KCR           3           5
# 4           ARI       LAD           5          12
# ...         ...       ...         ...         ...
# 12111       CIN       PIT           0           4
# 12112       OAK       SEA           2           3
# 12113       COL       SFG           7           3
# 12114       TOR       TBR           3          12
# 12115       LAA       TEX           2           9
#
#                                 link       date                KEY  CloseOU  \
# 0      /boxes/OAK/OAK201903200.shtml 2019-03-20   2019-03-20-OAK79      8.5
# 1      /boxes/OAK/OAK201903210.shtml 2019-03-21   2019-03-21-OAK45      9.0
# 2      /boxes/CIN/CIN201903280.shtml 2019-03-28   2019-03-28-CIN53      8.5
# 3      /boxes/KCA/KCA201903280.shtml 2019-03-28   2019-03-28-KCR53      8.5
# 4      /boxes/LAN/LAN201903280.shtml 2019-03-28  2019-03-28-LAD125      7.0
# ...                              ...        ...                ...      ...
# 12111  /boxes/PIT/PIT201510040.shtml 2015-10-04   2015-10-04-PIT40      7.5
# 12112  /boxes/SEA/SEA201510040.shtml 2015-10-04   2015-10-04-SEA32      7.5
# 12113  /boxes/SFN/SFN201510040.shtml 2015-10-04   2015-10-04-SFG37      7.5
# 12114  /boxes/TBA/TBA201510040.shtml 2015-10-04  2015-10-04-TBR123      8.5
# 12115  /boxes/TEX/TEX201510040.shtml 2015-10-04   2015-10-04-TEX92      8.5
#
#        Close_Odds  year  ...   OVER Total_Runs day_or_night  attendance   cli  \
# 0            -120  2019  ...   True         16            N      45,787  1.10
# 1            -130  2019  ...  False          9            N      46,451  1.01
# 2            -105  2019  ...  False          8            D      44,049  1.06
# 3            -105  2019  ...  False          8            N      31,675  1.08
# 4            -120  2019  ...   True         17            D      53,086  1.08
# ...           ...   ...  ...    ...        ...          ...         ...   ...
# 12111        -105  2015  ...  False          4            D      35,362   .00
# 12112        -115  2015  ...  False          5            D      22,402   .00
# 12113        -115  2015  ...   True         10            D      41,399   .00
# 12114        -120  2015  ...   True         15            D      15,815   .00
# 12115        -115  2015  ...   True         11            D      45,772  2.59
#
#                                                    other  Away_Pitcher_Name  \
# 0      Umpires: HP - Jeff Nelson, 1B - Tripp Gibson, ...     Marco Gonzales
# 1      Umpires: HP - Bill Welke, 1B - Lance Barksdale...      Yusei Kikuchi
# 2      Umpires: HP - Joe West, 1B - Eric Cooper, 2B -...    Jameson Taillon
# 3      Umpires: HP - Jerry Meals, 1B - Ron Kulpa, 2B ...       Carlos Rodon
# 4      Umpires: HP - Brian Gorman, 1B - Scott Barry, ...       Zack Greinke
# ...                                                  ...                ...
# 12111  Umpires: HP - Tim Welke, 1B - Todd Tichenor, 2...      Josh A. Smith
# 12112  Umpires: HP - Mike Estabrook, 1B - Ed Hickox, ...      Chris Bassitt
# 12113  Umpires: HP - Carlos Torres, 1B - Andy Fletche...  Christian Bergman
# 12114  Umpires: HP - Alfonso Marquez, 1B - Tom Hallio...       Mark Buehrle
# 12115  Umpires: HP - Gary Cederstrom, 1B - Quinn Wolc...   Garrett Richards
#
#                   Away_Pitcher_ID Home_Pitcher_Name  \
# 0      /players/g/gonzama02.shtml        Mike Fiers
# 1      /players/k/kikucyu01.shtml     Marco Estrada
# 2      /players/t/taillja01.shtml     Luis Castillo
# 3      /players/r/rodonca01.shtml       Brad Keller
# 4      /players/g/greinza01.shtml      Hyun Jin Ryu
# ...                           ...               ...
# 12111  /players/s/smithjo07.shtml         J.A. Happ
# 12112  /players/b/bassich01.shtml    Vidal Nuno III
# 12113  /players/b/bergmch01.shtml         Matt Cain
# 12114  /players/b/buehrma01.shtml        Matt Moore
# 12115  /players/r/richaga01.shtml       Cole Hamels
#
#                   Home_Pitcher_ID
# 0      /players/f/fiersmi01.shtml
# 1      /players/e/estrama01.shtml
# 2      /players/c/castilu02.shtml
# 3      /players/k/kellebr01.shtml
# 4        /players/r/ryuhy01.shtml
# ...                           ...
# 12111   /players/h/happja01.shtml
# 12112   /players/n/nunovi01.shtml
# 12113   /players/c/cainma01.shtml
# 12114  /players/m/moorema02.shtml
# 12115  /players/h/hamelco01.shtml
#
# [12116 rows x 23 columns]

# %%
game_data.to_pickle('../Merged DFs/Games_AllData.pkl')
